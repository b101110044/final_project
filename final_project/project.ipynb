# %%
read_file = 'C:/TMU_class_b101110044/pyphon_med_data_analysis/final_project/dataset/'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import missingno as mno
from sklearn import linear_model
# %matplotlib inline

# %%
read_file = pd.read_excel('C:/TMU_class_b101110044/pyphon_med_data_analysis/final_project/dataset/dataset.xlsx')
read_file.to_csv('C:/TMU_class_b101110044/pyphon_med_data_analysis/final_project/dataset/dataset.csv')

data_dir = 'C:/TMU_class_b101110044/pyphon_med_data_analysis/final_project/dataset/'
dataset = pd.read_csv(os.path.join(data_dir,'dataset.csv'))
X = dataset.iloc[:,1:11]
y = dataset.iloc[:, -1]

# %%
dataset.shape
# Out:
# (481, 13)

# %%
dataset.head()
# Out:
#    Unnamed: 0  number  sex(man=1,woman=0)  age  neck circumference（cm）  \
# 0           0       1                   1   37                    38.0
# 1           1       2                   1   31                    40.0
# 2           2       3                   1   43                    37.0
# 3           3       4                   1   30                    37.0
# 4           4       5                   1   53                    39.0
#
#    waist circumference（cm）        BMI  maximum interincisal distance（cm）  \
# 0                     83.0  22.491349                                6.0
# 1                     89.0  22.093170                                5.0
# 2                     86.0  22.491349                                6.0
# 3                     89.0  23.255019                                6.0
# 4                     99.0  27.335640                                5.0
#
#    Mallampati test  ratio of Height to thyro-sternum distance  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 481 non-null    int64
#  1   number                                     481 non-null    int64
#  2   sex(man=1,woman=0)                         481 non-null    int64
#  3   age                                        481 non-null    int64
#  4   neck circumference（cm）                     481 non-null    float64
#  5   waist circumference（cm）                    481 non-null    float64
#  6   BMI                                        481 non-null    float64
#  7   maximum interincisal distance（cm）          479 non-null    float64
#  8   Mallampati test                            481 non-null    int64
#  9   ratio of Height to thyro-sternum distance  481 non-null    float64
# ...

# %%
X.iloc[:,1:10].describe()
# Out:
#        sex(man=1,woman=0)         age  neck circumference（cm）  \
# count          481.000000  481.000000              481.000000
# mean             0.675676   47.316008               39.051975
# std              0.468609   12.933964                4.174501
# min              0.000000   14.000000               10.000000
# 25%              0.000000   38.000000               37.000000
# 50%              1.000000   46.000000               39.500000
# 75%              1.000000   58.000000               42.000000
# max              1.000000   77.000000               49.000000
#
#        waist circumference（cm）         BMI  maximum interincisal distance（cm）  \
# count               481.000000  481.000000                         479.000000
# mean                 94.974012   26.260271                           4.878914
# std                  11.318994    4.157346                           0.880207
# min                  62.000000    7.444444                           0.500000
# ...

# %% [markdown]
# # Data Visualization

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

X.iloc[:,2:10].plot(kind='box', color='r', subplots=True, layout=(3,3), figsize=(20,20))
pyplot.show()
# Out:
# c:\Users\Tin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Tin\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X.iloc[:,1:10].hist(figsize=(20,20))
pyplot.show()
